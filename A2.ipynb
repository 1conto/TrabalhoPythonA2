# %%
import os
import pandas as pd
import numpy as np

# %%
path = r"Dados\inpe_EM_BRAmz_results (1).xlsx"

data = pd.read_excel(path)

data
# Out:
#    Descrição dos atributos presentes nas planilhas "Sem degradação" e " Com degradação" comumente disponibilizadas na planilha.  \
# 0                                                 NaN
# 1   O nome da variável é normalmente formado por: ...
# 2   Alguns atributos são comuns em ambas as planil...
# 3                                                 NaN
# 4                                            Atributo
# 5                                                Year
# 6                                              D_Area
# 7                                           D_AreaAcc
# 8                                     VR_CO2_1stOrder
# 9                                     VR_CO2_2ndOrder
# 10                              VR_CO2_2ndOrderFire *
# 11                             VR_CO2_2ndOrderDecay *
# 12                             VR_CH42Eq_2ndOrderFire
# 13                              VR_N2OEq_2ndOrderFire
# 14                                       SV_AreaTotal
# ...
